# %%
import matplotlib
matplotlib.use('nbagg')

# %%
import numpy as np
from matplotlib import pyplot as plt
import scipy.optimize as optimize

# %%
x = np.random.standard_normal(100) * np.arange(100)
y = np.random.standard_normal(100) * np.arange(100)
z = np.arange(100)

# %%
def func(data, a, b):
    return data[:,0]*data[:,1]*a + b

# %%
guess = (1,1)
params, pcov = optimize.curve_fit(func, np.concatenate([x[:, None], y[:, None]], axis=-1), z, guess)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(x, y, p_z, label='parametric curve')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
